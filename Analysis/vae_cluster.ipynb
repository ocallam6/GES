# %%
from astropy.io import fits
import os

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import sklearn.decomposition
import seaborn as sn
import pickle
if("Analysis" in os.getcwd()):
    os.chdir("../Data_handling")

from pca_functions import Pca_Fitting
from gaia_query import gaia_cone, bailer_jones_cone, concatenate_gaia_bailer
from vae import Encoder,Decoder, VAE , loss_function, model_train
from sp_vae import ModelVAE,model_trains

os.chdir("../Analysis")
os.getcwd()
# Out:
# '/Users/mattocallaghan/GES/Analysis'

# %%
sn.set_style('darkgrid') # darkgrid, white grid, dark, white and ticks
plt.rc('axes', titlesize=18)     # fontsize of the axes title
plt.rc('axes', labelsize=14)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=13)    # fontsize of the tick labels
plt.rc('ytick', labelsize=13)    # fontsize of the tick labels
plt.rc('legend', fontsize=13)    # legend fontsize
plt.rc('font', size=13)

# %%
os.chdir('../cluster_files')

# %%
vae_data=pd.read_csv('vae_data.csv')
#vae_data=pd.read_csv('vae_data_full.csv')

# %%
os.chdir('../Analysis')

# %% [markdown]
# For now we will drop the nan values for training the VAE

# %%
vae_data.columns
# Out:
# Index(['Unnamed: 0', 'bp_rp', 'mean_absolute_mag_g_band', 'prob', 'ra', 'dec',
#        'parallax', 'VRAD', 'pmra', 'pmdec', 'phot_g_mean_mag', 'bp_g', 'g_rp',
#        'rgeo'],
#       dtype='object')

# %%
vae_data=vae_data.dropna()

# %%
vae_data
# Out:
#        Unnamed: 0     bp_rp  mean_absolute_mag_g_band           prob  \
# 0               0  1.330919                 38.262669  2.272232e-105
# 1               1  1.458172                 41.751920   1.560951e-97
# 2               2  1.252724                 39.021232   6.492006e-05
# 3               3  1.342695                 37.603998  1.407040e-289
# 4               4  1.233818                 37.747092   5.012303e-49
# ...           ...       ...                       ...            ...
# 25777       25777  1.685307                 41.518770   1.672779e-29
# 25778       25778  1.605724                 38.143671   0.000000e+00
# 25779       25779  2.963137                 41.491576   3.309349e-07
# 25780       25780  1.505640                 40.704406   2.134537e-18
# 25781       25781  2.548458                 42.088581   6.797550e-25
#
#                ra       dec  parallax    VRAD      pmra     pmdec  \
# 0      282.565031 -6.258065  0.558562   30.64  0.776237 -6.756839
# 1      282.583418 -6.192254  0.376980  105.47 -1.612175 -4.640347
# 2      282.592885 -6.329504  0.375033   39.07 -2.393408 -4.043109
# 3      282.596724 -6.241452  0.523459  -43.21 -3.040533 -0.931751
# 4      282.596739 -6.257442  0.395225   -5.76 -0.711199 -4.404408
# ...           ...       ...       ...     ...       ...       ...
# 25777  282.788470 -6.007469  0.030766    0.00 -2.850967 -5.665195
# 25778  282.780248 -6.007047  0.449862    0.00  1.577184  3.119071
# 25779  282.775456 -6.005157  0.002803    0.00 -1.806624 -4.939151
# 25780  282.703295 -6.011748  0.209325    0.00 -3.147602 -4.699169
# 25781  282.697090 -6.013477 -0.346574    0.00 -4.246188 -4.636766
#
#        phot_g_mean_mag      bp_g      g_rp        rgeo
# 0            16.820326  0.590866  0.740053  1942.98157
# 1            17.810553  0.413675  1.044496  6141.48389
# 2            16.887486  0.575531  0.677193  2671.46338
# 3            16.224398  0.585712  0.756983  1887.64343
# 4            15.882403  0.529069  0.704749  2360.14062
# ...                ...       ...       ...         ...
# 25777        17.267374  0.790930  0.894377  7084.01074
# 25778        16.531607  0.720057  0.885668  2100.93555
# 25779        17.039620  1.733685  1.229452  7769.46533
# 25780        17.225449  0.667429  0.838211  4963.53955
# 25781        17.837267  1.236076  1.312382  7083.74365
#
# [24575 rows x 14 columns]

# %%
from sklearn.preprocessing import  MinMaxScaler
import torch
scaler=MinMaxScaler()

# %%
column_names=['pmra', 'pmdec',
       'rgeo']


#column_names_no_p=['bp_rp','ra','dec','VRAD','pmra','pmdec','phot_g_mean_mag','bp_g','g_rp']
column_names
# Out:
# ['pmra', 'pmdec', 'rgeo']

# %%
#scaled_data=scaler.fit_transform(vae_data[['bp_rp','phot_g_mean_mag','rgeo','bp_g','g_rp']].values)
#scaled_data=scaler.fit_transform(vae_data[['bp_rp','mean_absolute_mag_g_band']].values)
scaled_data=scaler.fit_transform(vae_data[column_names].values)
#scaled_data=vae_data[column_names].values

# %% [markdown]
# # Scaled, non inverted HR diagram

# %%
plt.scatter(scaled_data.transpose()[1],scaled_data.transpose()[2],s=0.5)

# %% [markdown]
# # Variational Autoencoder

# %% [markdown]
# Here we are going to use two different ways and see how they compare.

# %%
import torch
import torch.nn as nn 
import torch.nn.functional as F 
from torch.optim import Adam
from torch.utils.data import DataLoader


DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Latent parameters

# %%
batch_size = 4915 #617 #factor for 1090
lr = 1e-3
epochs = 100
zdim=5

# %%
vae_dataset=DataLoader(torch.tensor(scaled_data).float(),batch_size=batch_size)

# %%
encoder = Encoder(input_dim=scaled_data.shape[1], hidden_dims=[50,5], z_dim=zdim,dropout=0.2)
decoder = Decoder(output_dim=scaled_data.shape[1], hidden_dims = [5,50], z_dim=zdim,dropout=0.2)
model = VAE(Encoder=encoder, Decoder=decoder).to(DEVICE)
optimizer=Adam(model.parameters(),lr=lr)

# %% [markdown]
# ### The github defined one.

# %% [markdown]
# #----------

# %%
'''model1=ModelVAE(h_dim=200,z_dim=zdim,activation=F.relu,distribution='vmf')
optimizer1=Adam(model1.parameters(),lr=lr)
print("Start training VAE...")
model1.train()
model_trains(vae_spec=vae_dataset,model=model1,optimizer=optimizer1,epochs=epochs,batch_size=batch_size)'''
# Out:
# 'model1=ModelVAE(h_dim=200,z_dim=zdim,activation=F.relu,distribution=\'vmf\')\noptimizer1=Adam(model1.parameters(),lr=lr)\nprint("Start training VAE...")\nmodel1.train()\nmodel_trains(vae_spec=vae_dataset,model=model1,optimizer=optimizer1,epochs=epochs,batch_size=batch_size)'

# %% [markdown]
# #--------------

# %% [markdown]
# ### Train my original explicit one

# %%
print("Start training VAE...")
model.train()
z_an,kld=model_train(vae_spec=vae_dataset,model=model,optimizer=optimizer,loss_function=loss_function,epochs=epochs,batch_size=batch_size)
# Out:
# Start training VAE...
# 	Epoch 1 complete! 	Average Loss:  2.7392009870930822
# Overall Loss:  53852.69140625
# KLD Loss:  tensor(3678.2146, grad_fn=<MulBackward0>)
# 	Epoch 2 complete! 	Average Loss:  2.7075723828522382
# Overall Loss:  53230.873046875
# KLD Loss:  tensor(3613.4329, grad_fn=<MulBackward0>)
# 	Epoch 3 complete! 	Average Loss:  2.6786619106847662
# Overall Loss:  52662.4931640625
# KLD Loss:  tensor(3554.6179, grad_fn=<MulBackward0>)
# 	Epoch 4 complete! 	Average Loss:  2.653541752765768
# Overall Loss:  52168.630859375
# KLD Loss:  tensor(3498.6785, grad_fn=<MulBackward0>)
# 	Epoch 5 complete! 	Average Loss:  2.6299404326678535
# Overall Loss:  51704.62890625
# KLD Loss:  tensor(3444.1223, grad_fn=<MulBackward0>)
# 	Epoch 6 complete! 	Average Loss:  2.6114260296127925
# Overall Loss:  51340.6357421875
# KLD Loss:  tensor(3388.1313, grad_fn=<MulBackward0>)
# 	Epoch 7 complete! 	Average Loss:  2.593202161352365
# Overall Loss:  50982.3544921875
# KLD Loss:  tensor(3327.7869, grad_fn=<MulBackward0>)
# 	Epoch 8 complete! 	Average Loss:  2.5778434559384538
# Overall Loss:  50680.40234375
# KLD Loss:  tensor(3262.1555, grad_fn=<MulBackward0>)
# 	Epoch 9 complete! 	Average Loss:  2.56476193929616
# Overall Loss:  50423.2197265625
# KLD Loss:  tensor(3192.0044, grad_fn=<MulBackward0>)
# 	Epoch 10 complete! 	Average Loss:  2.5526748672749235
# Overall Loss:  50185.587890625
# KLD Loss:  tensor(3119.2771, grad_fn=<MulBackward0>)
# 	Epoch 11 complete! 	Average Loss:  2.543217808208291
# Overall Loss:  49999.662109375
# KLD Loss:  tensor(3045.0593, grad_fn=<MulBackward0>)
# 	Epoch 12 complete! 	Average Loss:  2.5345751804107324
# Overall Loss:  49829.748046875
# KLD Loss:  tensor(2969.8972, grad_fn=<MulBackward0>)
# 	Epoch 13 complete! 	Average Loss:  2.5269317657998474
# Overall Loss:  49679.478515625
# KLD Loss:  tensor(2893.1992, grad_fn=<MulBackward0>)
# 	Epoch 14 complete! 	Average Loss:  2.520623549561292
# Overall Loss:  49555.458984375
# KLD Loss:  tensor(2815.1079, grad_fn=<MulBackward0>)
# 	Epoch 15 complete! 	Average Loss:  2.5149566557254577
# Overall Loss:  49444.0478515625
# KLD Loss:  tensor(2735.8306, grad_fn=<MulBackward0>)
# 	Epoch 16 complete! 	Average Loss:  2.509950506262716
# Overall Loss:  49345.626953125
# KLD Loss:  tensor(2656.2642, grad_fn=<MulBackward0>)
# 	Epoch 17 complete! 	Average Loss:  2.5051888948054426
# Overall Loss:  49252.013671875
# KLD Loss:  tensor(2577.3794, grad_fn=<MulBackward0>)
# 	Epoch 18 complete! 	Average Loss:  2.5018282978605035
# Overall Loss:  49185.9443359375
# KLD Loss:  tensor(2499.9102, grad_fn=<MulBackward0>)
# 	Epoch 19 complete! 	Average Loss:  2.498285203935656
# Overall Loss:  49116.287109375
# KLD Loss:  tensor(2424.4529, grad_fn=<MulBackward0>)
# 	Epoch 20 complete! 	Average Loss:  2.4951065078999237
# Overall Loss:  49053.7939453125
# KLD Loss:  tensor(2351.4346, grad_fn=<MulBackward0>)
# 	Epoch 21 complete! 	Average Loss:  2.4910907795810022
# Overall Loss:  48974.8447265625
# KLD Loss:  tensor(2281.0962, grad_fn=<MulBackward0>)
# 	Epoch 22 complete! 	Average Loss:  2.488881244834054
# Overall Loss:  48931.4052734375
# KLD Loss:  tensor(2213.4275, grad_fn=<MulBackward0>)
# 	Epoch 23 complete! 	Average Loss:  2.4863890235567143
# Overall Loss:  48882.408203125
# KLD Loss:  tensor(2148.0640, grad_fn=<MulBackward0>)
# 	Epoch 24 complete! 	Average Loss:  2.4838688863015004
# Overall Loss:  48832.8623046875
# KLD Loss:  tensor(2084.5635, grad_fn=<MulBackward0>)
# 	Epoch 25 complete! 	Average Loss:  2.4817319231625126
# Overall Loss:  48790.849609375
# KLD Loss:  tensor(2022.4590, grad_fn=<MulBackward0>)
# 	Epoch 26 complete! 	Average Loss:  2.4795632689312055
# Overall Loss:  48748.2138671875
# KLD Loss:  tensor(1961.2705, grad_fn=<MulBackward0>)
# 	Epoch 27 complete! 	Average Loss:  2.4776417853509662
# Overall Loss:  48710.4375
# KLD Loss:  tensor(1900.7012, grad_fn=<MulBackward0>)
# 	Epoch 28 complete! 	Average Loss:  2.475946709292345
# Overall Loss:  48677.1123046875
# KLD Loss:  tensor(1840.4789, grad_fn=<MulBackward0>)
# 	Epoch 29 complete! 	Average Loss:  2.473669570193286
# Overall Loss:  48632.34375
# KLD Loss:  tensor(1780.4115, grad_fn=<MulBackward0>)
# 	Epoch 30 complete! 	Average Loss:  2.4718799672558496
# Overall Loss:  48597.16015625
# KLD Loss:  tensor(1720.3455, grad_fn=<MulBackward0>)
# 	Epoch 31 complete! 	Average Loss:  2.470011583640641
# Overall Loss:  48560.427734375
# KLD Loss:  tensor(1660.1498, grad_fn=<MulBackward0>)
# 	Epoch 32 complete! 	Average Loss:  2.4679052187976858
# Overall Loss:  48519.0166015625
# KLD Loss:  tensor(1599.6921, grad_fn=<MulBackward0>)
# 	Epoch 33 complete! 	Average Loss:  2.466017711247457
# Overall Loss:  48481.908203125
# KLD Loss:  tensor(1538.9670, grad_fn=<MulBackward0>)
# 	Epoch 34 complete! 	Average Loss:  2.4639266952250765
# Overall Loss:  48440.798828125
# KLD Loss:  tensor(1477.8624, grad_fn=<MulBackward0>)
# 	Epoch 35 complete! 	Average Loss:  2.4624671664388353
# Overall Loss:  48412.1044921875
# KLD Loss:  tensor(1416.2567, grad_fn=<MulBackward0>)
# 	Epoch 36 complete! 	Average Loss:  2.4605960508329097
# Overall Loss:  48375.318359375
# KLD Loss:  tensor(1354.1135, grad_fn=<MulBackward0>)
# 	Epoch 37 complete! 	Average Loss:  2.458577159365463
# Overall Loss:  48335.626953125
# KLD Loss:  tensor(1291.3431, grad_fn=<MulBackward0>)
# 	Epoch 38 complete! 	Average Loss:  2.4568208370422178
# Overall Loss:  48301.09765625
# KLD Loss:  tensor(1227.9265, grad_fn=<MulBackward0>)
# 	Epoch 39 complete! 	Average Loss:  2.4550946162894203
# Overall Loss:  48267.16015625
# KLD Loss:  tensor(1163.8180, grad_fn=<MulBackward0>)
# 	Epoch 40 complete! 	Average Loss:  2.4534605381326298
# Overall Loss:  48235.0341796875
# KLD Loss:  tensor(1099.0105, grad_fn=<MulBackward0>)
# 	Epoch 41 complete! 	Average Loss:  2.4515124300610376
# Overall Loss:  48196.734375
# KLD Loss:  tensor(1033.5862, grad_fn=<MulBackward0>)
# 	Epoch 42 complete! 	Average Loss:  2.4498425379895727
# Overall Loss:  48163.904296875
# KLD Loss:  tensor(967.6240, grad_fn=<MulBackward0>)
# 	Epoch 43 complete! 	Average Loss:  2.4477896208195573
# Overall Loss:  48123.5439453125
# KLD Loss:  tensor(901.2650, grad_fn=<MulBackward0>)
# 	Epoch 44 complete! 	Average Loss:  2.4458722600616736
# Overall Loss:  48085.8486328125
# KLD Loss:  tensor(834.7778, grad_fn=<MulBackward0>)
# 	Epoch 45 complete! 	Average Loss:  2.444127561117116
# Overall Loss:  48051.5478515625
# KLD Loss:  tensor(768.5187, grad_fn=<MulBackward0>)
# 	Epoch 46 complete! 	Average Loss:  2.442479375953713
# Overall Loss:  48019.14453125
# KLD Loss:  tensor(702.8128, grad_fn=<MulBackward0>)
# 	Epoch 47 complete! 	Average Loss:  2.440766070066124
# Overall Loss:  47985.4609375
# KLD Loss:  tensor(638.1921, grad_fn=<MulBackward0>)
# 	Epoch 48 complete! 	Average Loss:  2.439040197021236
# Overall Loss:  47951.5302734375
# KLD Loss:  tensor(575.2266, grad_fn=<MulBackward0>)
# 	Epoch 49 complete! 	Average Loss:  2.4373889321592066
# Overall Loss:  47919.06640625
# KLD Loss:  tensor(514.6135, grad_fn=<MulBackward0>)
# 	Epoch 50 complete! 	Average Loss:  2.4358173917535604
# Overall Loss:  47888.169921875
# KLD Loss:  tensor(457.0539, grad_fn=<MulBackward0>)
# 	Epoch 51 complete! 	Average Loss:  2.434371771283698
# Overall Loss:  47859.7490234375
# KLD Loss:  tensor(403.0782, grad_fn=<MulBackward0>)
# 	Epoch 52 complete! 	Average Loss:  2.432927939025941
# Overall Loss:  47831.36328125
# KLD Loss:  tensor(353.2748, grad_fn=<MulBackward0>)
# 	Epoch 53 complete! 	Average Loss:  2.431695562849695
# Overall Loss:  47807.134765625
# KLD Loss:  tensor(308.1058, grad_fn=<MulBackward0>)
# 	Epoch 54 complete! 	Average Loss:  2.4305343674497712
# Overall Loss:  47784.3056640625
# KLD Loss:  tensor(267.6248, grad_fn=<MulBackward0>)
# 	Epoch 55 complete! 	Average Loss:  2.4296107062245675
# Overall Loss:  47766.146484375
# KLD Loss:  tensor(231.9626, grad_fn=<MulBackward0>)
# 	Epoch 56 complete! 	Average Loss:  2.428705523191124
# Overall Loss:  47748.3505859375
# KLD Loss:  tensor(200.9403, grad_fn=<MulBackward0>)
# 	Epoch 57 complete! 	Average Loss:  2.428003749284715
# Overall Loss:  47734.5537109375
# KLD Loss:  tensor(174.1924, grad_fn=<MulBackward0>)
# 	Epoch 58 complete! 	Average Loss:  2.427373801897889
# Overall Loss:  47722.1689453125
# KLD Loss:  tensor(151.3209, grad_fn=<MulBackward0>)
# 	Epoch 59 complete! 	Average Loss:  2.4269471642929807
# Overall Loss:  47713.78125
# KLD Loss:  tensor(131.9341, grad_fn=<MulBackward0>)
# 	Epoch 60 complete! 	Average Loss:  2.426302712519074
# Overall Loss:  47701.111328125
# KLD Loss:  tensor(115.4644, grad_fn=<MulBackward0>)
# 	Epoch 61 complete! 	Average Loss:  2.4258761742592827
# Overall Loss:  47692.7255859375
# KLD Loss:  tensor(101.6197, grad_fn=<MulBackward0>)
# 	Epoch 62 complete! 	Average Loss:  2.4256644698149796
# Overall Loss:  47688.5634765625
# KLD Loss:  tensor(89.9739, grad_fn=<MulBackward0>)
# 	Epoch 63 complete! 	Average Loss:  2.42529858174911
# Overall Loss:  47681.3701171875
# KLD Loss:  tensor(80.0817, grad_fn=<MulBackward0>)
# 	Epoch 64 complete! 	Average Loss:  2.425083300880595
# Overall Loss:  47677.1376953125
# KLD Loss:  tensor(71.7226, grad_fn=<MulBackward0>)
# 	Epoch 65 complete! 	Average Loss:  2.4248694108437183
# Overall Loss:  47672.9326171875
# KLD Loss:  tensor(64.6270, grad_fn=<MulBackward0>)
# 	Epoch 66 complete! 	Average Loss:  2.4246056495581128
# Overall Loss:  47667.7470703125
# KLD Loss:  tensor(58.4624, grad_fn=<MulBackward0>)
# 	Epoch 67 complete! 	Average Loss:  2.424423500286114
# Overall Loss:  47664.166015625
# KLD Loss:  tensor(53.2118, grad_fn=<MulBackward0>)
# 	Epoch 68 complete! 	Average Loss:  2.4243536606688707
# Overall Loss:  47662.79296875
# KLD Loss:  tensor(48.6904, grad_fn=<MulBackward0>)
# 	Epoch 69 complete! 	Average Loss:  2.4241839295364955
# Overall Loss:  47659.4560546875
# KLD Loss:  tensor(44.7668, grad_fn=<MulBackward0>)
# 	Epoch 70 complete! 	Average Loss:  2.4241267067491097
# Overall Loss:  47658.3310546875
# KLD Loss:  tensor(41.3316, grad_fn=<MulBackward0>)
# 	Epoch 71 complete! 	Average Loss:  2.424024679313962
# Overall Loss:  47656.3251953125
# KLD Loss:  tensor(38.3233, grad_fn=<MulBackward0>)
# 	Epoch 72 complete! 	Average Loss:  2.4239997933621567
# Overall Loss:  47655.8359375
# KLD Loss:  tensor(35.6844, grad_fn=<MulBackward0>)
# 	Epoch 73 complete! 	Average Loss:  2.423814365701297
# Overall Loss:  47652.1904296875
# KLD Loss:  tensor(33.3169, grad_fn=<MulBackward0>)
# 	Epoch 74 complete! 	Average Loss:  2.4238236544697354
# Overall Loss:  47652.373046875
# KLD Loss:  tensor(31.1987, grad_fn=<MulBackward0>)
# 	Epoch 75 complete! 	Average Loss:  2.423736628147253
# Overall Loss:  47650.662109375
# KLD Loss:  tensor(29.3210, grad_fn=<MulBackward0>)
# 	Epoch 76 complete! 	Average Loss:  2.4236764746789166
# Overall Loss:  47649.4794921875
# KLD Loss:  tensor(27.6764, grad_fn=<MulBackward0>)
# 	Epoch 77 complete! 	Average Loss:  2.4236266531027466
# Overall Loss:  47648.5
# KLD Loss:  tensor(26.1686, grad_fn=<MulBackward0>)
# 	Epoch 78 complete! 	Average Loss:  2.4236126454412514
# Overall Loss:  47648.224609375
# KLD Loss:  tensor(24.8600, grad_fn=<MulBackward0>)
# 	Epoch 79 complete! 	Average Loss:  2.4236444358786877
# Overall Loss:  47648.849609375
# KLD Loss:  tensor(23.5831, grad_fn=<MulBackward0>)
# 	Epoch 80 complete! 	Average Loss:  2.4236100624682098
# Overall Loss:  47648.173828125
# KLD Loss:  tensor(22.4195, grad_fn=<MulBackward0>)
# 	Epoch 81 complete! 	Average Loss:  2.4235304870295016
# Overall Loss:  47646.609375
# KLD Loss:  tensor(21.4104, grad_fn=<MulBackward0>)
# 	Epoch 82 complete! 	Average Loss:  2.4235406699039928
# Overall Loss:  47646.8095703125
# KLD Loss:  tensor(20.4488, grad_fn=<MulBackward0>)
# 	Epoch 83 complete! 	Average Loss:  2.4234194688612667
# Overall Loss:  47644.4267578125
# KLD Loss:  tensor(19.5359, grad_fn=<MulBackward0>)
# 	Epoch 84 complete! 	Average Loss:  2.4234944247520347
# Overall Loss:  47645.900390625
# KLD Loss:  tensor(18.7222, grad_fn=<MulBackward0>)
# 	Epoch 85 complete! 	Average Loss:  2.4233897149987285
# Overall Loss:  47643.841796875
# KLD Loss:  tensor(17.9734, grad_fn=<MulBackward0>)
# 	Epoch 86 complete! 	Average Loss:  2.4234124153579604
# Overall Loss:  47644.2880859375
# KLD Loss:  tensor(17.2908, grad_fn=<MulBackward0>)
# 	Epoch 87 complete! 	Average Loss:  2.4234100807477112
# Overall Loss:  47644.2421875
# KLD Loss:  tensor(16.6403, grad_fn=<MulBackward0>)
# 	Epoch 88 complete! 	Average Loss:  2.42339890442205
# Overall Loss:  47644.0224609375
# KLD Loss:  tensor(16.0512, grad_fn=<MulBackward0>)
# 	Epoch 89 complete! 	Average Loss:  2.4233349758392677
# Overall Loss:  47642.765625
# KLD Loss:  tensor(15.5104, grad_fn=<MulBackward0>)
# 	Epoch 90 complete! 	Average Loss:  2.4234008913243894
# Overall Loss:  47644.0615234375
# KLD Loss:  tensor(14.9902, grad_fn=<MulBackward0>)
# 	Epoch 91 complete! 	Average Loss:  2.4233814693540183
# Overall Loss:  47643.6796875
# KLD Loss:  tensor(14.5248, grad_fn=<MulBackward0>)
# 	Epoch 92 complete! 	Average Loss:  2.4233115800642167
# Overall Loss:  47642.3056640625
# KLD Loss:  tensor(14.0975, grad_fn=<MulBackward0>)
# 	Epoch 93 complete! 	Average Loss:  2.4232899725012715
# Overall Loss:  47641.880859375
# KLD Loss:  tensor(13.6753, grad_fn=<MulBackward0>)
# 	Epoch 94 complete! 	Average Loss:  2.423335522237411
# Overall Loss:  47642.7763671875
# KLD Loss:  tensor(13.2798, grad_fn=<MulBackward0>)
# 	Epoch 95 complete! 	Average Loss:  2.423285800006358
# Overall Loss:  47641.798828125
# KLD Loss:  tensor(12.9215, grad_fn=<MulBackward0>)
# 	Epoch 96 complete! 	Average Loss:  2.4232757661495423
# Overall Loss:  47641.6015625
# KLD Loss:  tensor(12.5632, grad_fn=<MulBackward0>)
# 	Epoch 97 complete! 	Average Loss:  2.4232753190965157
# Overall Loss:  47641.5927734375
# KLD Loss:  tensor(12.2448, grad_fn=<MulBackward0>)
# 	Epoch 98 complete! 	Average Loss:  2.423207963107197
# Overall Loss:  47640.2685546875
# KLD Loss:  tensor(11.9023, grad_fn=<MulBackward0>)
# 	Epoch 99 complete! 	Average Loss:  2.4232631493196846
# Overall Loss:  47641.353515625
# KLD Loss:  tensor(11.6240, grad_fn=<MulBackward0>)
# 	Epoch 100 complete! 	Average Loss:  2.4232302660859615
# Overall Loss:  47640.70703125
# KLD Loss:  tensor(11.3494, grad_fn=<MulBackward0>)
# Finish!!

# %% [markdown]
# ### Look at the KLD of main model.

# %%
for i in range (len(z_an)):
    z_an[i]=z_an[i].detach().numpy()

for i in range (len(kld)):
    kld[i]=kld[i].detach().numpy()

# %%
plt.plot(kld)

# %% [markdown]
# # Model evaluations

# %%
'''model1.eval()
(z_mean, z_var), (q_z, p_z), z1, x_=model1(torch.tensor(scaled_data).float())
z1=z1.detach().numpy()
x_=x_.detach().numpy()'''
# Out:
# 'model1.eval()\n(z_mean, z_var), (q_z, p_z), z1, x_=model1(torch.tensor(scaled_data).float())\nz1=z1.detach().numpy()\nx_=x_.detach().numpy()'

# %%
model.eval()
x_recon=model(torch.tensor(scaled_data).float())[0].detach().numpy()
zmean=model(torch.tensor(scaled_data).float())[1].detach().numpy()
z=model(torch.tensor(scaled_data).float())[3].detach().numpy()

# %% [markdown]
# # Compare the reconstructions

# %%
plt.scatter(x_recon.transpose()[1], x_recon.transpose()[2],s=0.5)
#plt.scatter(x_.transpose()[0], x_.transpose()[1],s=0.5)

# %%
z_list=['z1','z2','z3','z4','z5']

# %%
vae_data[z_list]=z

# %%
#vae_data[['z11','z12','z13']]=z1

# %%
plt.figure(figsize=(15,10))
sn.pairplot(vae_data[z_list[0:3]])
#sn.pairplot(vae_data[['z11','z12','z13']])

# %%
fig = plt.figure(figsize=(15,15))


ax = fig.add_subplot(111, projection='3d') # Method 2

x=vae_data[vae_data['prob']<=0.9]
y=vae_data[vae_data['prob']>0.9]
ax.scatter(x['z1'], x['z2'], x['z3'],s=5,alpha=0.3)
ax.scatter(y['z1'], y['z2'], y['z3'],s=5)


plt.show()

# %%
plt.figure(figsize=(15,10))
sn.scatterplot(data=vae_data[vae_data['prob']<=0.9],x='z1',y='z2')
sn.scatterplot(data=vae_data[vae_data['prob']>0.9],x='z1',y='z2')
# Out:
# <AxesSubplot:xlabel='z1', ylabel='z2'>

# %% [markdown]
# # Now let us see if we can cluster well on this latent space

# %%
from sklearn.mixture import GaussianMixture

# %%
gm = GaussianMixture(n_components=3 ,random_state=0).fit(vae_data[z_list].values)

# %%
z_list
# Out:
# ['z1', 'z2', 'z3', 'z4', 'z5']

# %%
i=1
plt.hist(gm.predict_proba(vae_data[vae_data['prob']<=0.9][z_list].values).transpose()[i])
plt.hist(gm.predict_proba(vae_data[vae_data['prob']>0.9][z_list].values).transpose()[i],color='r')
plt.show()

vae_data['prob2']=gm.predict_proba(vae_data[z_list].values).transpose()[i]

# %% [markdown]
# This seems to be working okay.

# %% [markdown]
# Check it on a HR diagram

# %%
data_for_hr1_full=vae_data[vae_data['prob2']>0.9]
data_for_hr2_full=vae_data[vae_data['prob']>0.9]
both_solution=data_for_hr1_full[vae_data['prob']>0.9]
data_for_hr1_full=data_for_hr1_full[data_for_hr1_full['prob']<=0.9]
data_for_hr2_full=data_for_hr2_full[data_for_hr2_full['prob2']<=0.9]
# Out:
# /var/folders/tm/gnjj0w_d6vj9x6q_ww3f6jsw0000gn/T/ipykernel_3689/1280756406.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   both_solution=data_for_hr1_full[vae_data['prob']>0.9]

# %%
f, axes = plt.subplots(1, 1)
f.set_figheight(12)
f.set_figwidth(12)

scatter=data_for_hr1_full
sn.scatterplot(x=scatter['bp_rp'],y=scatter['mean_absolute_mag_g_band'],ax=axes,s=10,label='True Full solution',color='b')

scatter=data_for_hr2_full
sn.scatterplot(x=scatter['bp_rp'],y=scatter['mean_absolute_mag_g_band'],ax=axes,label='True astrometric',s=10,color='g')

scatter=both_solution
sn.scatterplot(x=scatter['bp_rp'],y=scatter['mean_absolute_mag_g_band'],ax=axes,label='both classified',s=10,color='red')

#axes.set_xlim(0,2.5)
axes.invert_yaxis()
plt.legend()
axes.set_title("NGC 6705 p>0.9")
plt.show()

# %%
sn.scatterplot(data=vae_data,x='pmra',y='pmdec',hue='prob2')
# Out:
# <AxesSubplot:xlabel='pmra', ylabel='pmdec'>
