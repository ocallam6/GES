# %%
from astropy.io import fits
import os

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import sklearn.decomposition
import seaborn as sn
import pickle
if("Analysis" in os.getcwd()):
    os.chdir("../Data_handling")

from pca_functions import Pca_Fitting
from gaia_query import gaia_cone, bailer_jones_cone, concatenate_gaia_bailer
from vae import Encoder,Decoder, VAE , loss_function, model_train
from sp_vae import ModelVAE,model_trains

os.chdir("../Analysis")
os.getcwd()
# Out:
# '/Users/mattocallaghan/GES/Analysis'

# %%
sn.set_style('darkgrid') # darkgrid, white grid, dark, white and ticks
plt.rc('axes', titlesize=18)     # fontsize of the axes title
plt.rc('axes', labelsize=14)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=13)    # fontsize of the tick labels
plt.rc('ytick', labelsize=13)    # fontsize of the tick labels
plt.rc('legend', fontsize=13)    # legend fontsize
plt.rc('font', size=13)

# %%
os.chdir('../cluster_files')

# %%
vae_data=pd.read_csv('vae_data.csv')
#vae_data=pd.read_csv('vae_data_full.csv')

# %%
os.chdir('../Analysis')

# %% [markdown]
# For now we will drop the nan values for training the VAE

# %%
vae_data.columns
# Out:
# Index(['Unnamed: 0', 'bp_rp', 'mean_absolute_mag_g_band', 'prob', 'ra', 'dec',
#        'parallax', 'VRAD', 'pmra', 'pmdec', 'phot_g_mean_mag', 'bp_g', 'g_rp',
#        'rgeo'],
#       dtype='object')

# %%
vae_data=vae_data.dropna()

# %%
vae_data
# Out:
#        Unnamed: 0     bp_rp  mean_absolute_mag_g_band           prob  \
# 0               0  1.330919                 38.262669  2.272232e-105
# 1               1  1.458172                 41.751920   1.560951e-97
# 2               2  1.252724                 39.021232   6.492006e-05
# 3               3  1.342695                 37.603998  1.407040e-289
# 4               4  1.233818                 37.747092   5.012303e-49
# ...           ...       ...                       ...            ...
# 25777       25777  1.685307                 41.518770   1.672779e-29
# 25778       25778  1.605724                 38.143671   0.000000e+00
# 25779       25779  2.963137                 41.491576   3.309349e-07
# 25780       25780  1.505640                 40.704406   2.134537e-18
# 25781       25781  2.548458                 42.088581   6.797550e-25
#
#                ra       dec  parallax    VRAD      pmra     pmdec  \
# 0      282.565031 -6.258065  0.558562   30.64  0.776237 -6.756839
# 1      282.583418 -6.192254  0.376980  105.47 -1.612175 -4.640347
# 2      282.592885 -6.329504  0.375033   39.07 -2.393408 -4.043109
# 3      282.596724 -6.241452  0.523459  -43.21 -3.040533 -0.931751
# 4      282.596739 -6.257442  0.395225   -5.76 -0.711199 -4.404408
# ...           ...       ...       ...     ...       ...       ...
# 25777  282.788470 -6.007469  0.030766    0.00 -2.850967 -5.665195
# 25778  282.780248 -6.007047  0.449862    0.00  1.577184  3.119071
# 25779  282.775456 -6.005157  0.002803    0.00 -1.806624 -4.939151
# 25780  282.703295 -6.011748  0.209325    0.00 -3.147602 -4.699169
# 25781  282.697090 -6.013477 -0.346574    0.00 -4.246188 -4.636766
#
#        phot_g_mean_mag      bp_g      g_rp        rgeo
# 0            16.820326  0.590866  0.740053  1942.98157
# 1            17.810553  0.413675  1.044496  6141.48389
# 2            16.887486  0.575531  0.677193  2671.46338
# 3            16.224398  0.585712  0.756983  1887.64343
# 4            15.882403  0.529069  0.704749  2360.14062
# ...                ...       ...       ...         ...
# 25777        17.267374  0.790930  0.894377  7084.01074
# 25778        16.531607  0.720057  0.885668  2100.93555
# 25779        17.039620  1.733685  1.229452  7769.46533
# 25780        17.225449  0.667429  0.838211  4963.53955
# 25781        17.837267  1.236076  1.312382  7083.74365
#
# [24575 rows x 14 columns]

# %%
from sklearn.preprocessing import  MinMaxScaler
import torch
scaler=MinMaxScaler()

# %%
column_names=['bp_rp','ra','dec','pmra','pmdec','mean_absolute_mag_g_band','parallax','rgeo']
#column_names_no_p=['bp_rp','ra','dec','VRAD','pmra','pmdec','phot_g_mean_mag','bp_g','g_rp']
column_names
# Out:
# ['bp_rp',
#  'ra',
#  'dec',
#  'pmra',
#  'pmdec',
#  'mean_absolute_mag_g_band',
#  'parallax',
#  'rgeo']

# %%
#scaled_data=scaler.fit_transform(vae_data[['bp_rp','phot_g_mean_mag','rgeo','bp_g','g_rp']].values)
#scaled_data=scaler.fit_transform(vae_data[['bp_rp','mean_absolute_mag_g_band']].values)
scaled_data=scaler.fit_transform(vae_data[column_names].values)

# %% [markdown]
# # Scaled, non inverted HR diagram

# %%
plt.scatter(scaled_data.transpose()[1],scaled_data.transpose()[2],s=0.5)

# %% [markdown]
# # Variational Autoencoder

# %% [markdown]
# Here we are going to use two different ways and see how they compare.

# %%
import torch
import torch.nn as nn 
import torch.nn.functional as F 
from torch.optim import Adam
from torch.utils.data import DataLoader


DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Latent parameters

# %%
batch_size = 983 #617 #factor for 1090
lr = 1e-3
epochs = 500
zdim=3

# %%
vae_dataset=DataLoader(torch.tensor(scaled_data).float(),batch_size=batch_size)

# %%
encoder = Encoder(input_dim=scaled_data.shape[1], hidden_dims=[500,200], z_dim=zdim,dropout=0.2)
decoder = Decoder(output_dim=scaled_data.shape[1], hidden_dims = [200,500], z_dim=zdim,dropout=0.2)
model = VAE(Encoder=encoder, Decoder=decoder).to(DEVICE)
optimizer=Adam(model.parameters(),lr=lr)

# %% [markdown]
# ### The github defined one.

# %% [markdown]
# #----------

# %%
'''model1=ModelVAE(h_dim=200,z_dim=zdim,activation=F.relu,distribution='vmf')
optimizer1=Adam(model1.parameters(),lr=lr)
print("Start training VAE...")
model1.train()
model_trains(vae_spec=vae_dataset,model=model1,optimizer=optimizer1,epochs=epochs,batch_size=batch_size)'''
# Out:
# 'model1=ModelVAE(h_dim=200,z_dim=zdim,activation=F.relu,distribution=\'vmf\')\noptimizer1=Adam(model1.parameters(),lr=lr)\nprint("Start training VAE...")\nmodel1.train()\nmodel_trains(vae_spec=vae_dataset,model=model1,optimizer=optimizer1,epochs=epochs,batch_size=batch_size)'

# %% [markdown]
# #--------------

# %% [markdown]
# ### Train my original explicit one

# %%
print("Start training VAE...")
model.train()
z_an,kld=model_train(vae_spec=vae_dataset,model=model,optimizer=optimizer,loss_function=loss_function,epochs=epochs,batch_size=batch_size)
# Out:
# Start training VAE...
# 	Epoch 1 complete! 	Average Loss:  5.531334608924635
# Overall Loss:  130495.24609375
# 	Epoch 2 complete! 	Average Loss:  5.497593343844047
# Overall Loss:  129699.22216796875
# 	Epoch 3 complete! 	Average Loss:  5.3785434126570975
# Overall Loss:  126890.59619140625
# 	Epoch 4 complete! 	Average Loss:  5.366184093621514
# Overall Loss:  126599.01513671875
# 	Epoch 5 complete! 	Average Loss:  5.365274113046795
# Overall Loss:  126577.546875
# 	Epoch 6 complete! 	Average Loss:  5.363345679447747
# Overall Loss:  126532.05126953125
# 	Epoch 7 complete! 	Average Loss:  5.359746116102651
# Overall Loss:  126447.13037109375
# 	Epoch 8 complete! 	Average Loss:  5.357595128744649
# Overall Loss:  126396.38427734375
# 	Epoch 9 complete! 	Average Loss:  5.356322083161135
# Overall Loss:  126366.3505859375
# 	Epoch 10 complete! 	Average Loss:  5.3547721751547135
# Overall Loss:  126329.78515625
# 	Epoch 11 complete! 	Average Loss:  5.353701296884272
# Overall Loss:  126304.52099609375
# 	Epoch 12 complete! 	Average Loss:  5.352822630718305
# Overall Loss:  126283.79150390625
# 	Epoch 13 complete! 	Average Loss:  5.351969214769572
# Overall Loss:  126263.65771484375
# 	Epoch 14 complete! 	Average Loss:  5.3513138681478365
# Overall Loss:  126248.19677734375
# 	Epoch 15 complete! 	Average Loss:  5.351717933714289
# Overall Loss:  126257.7294921875
# 	Epoch 16 complete! 	Average Loss:  5.351059648132842
# Overall Loss:  126242.19921875
# 	Epoch 17 complete! 	Average Loss:  5.350710160290035
# Overall Loss:  126233.9541015625
# 	Epoch 18 complete! 	Average Loss:  5.3504472475773035
# Overall Loss:  126227.75146484375
# 	Epoch 19 complete! 	Average Loss:  5.349603641958874
# Overall Loss:  126207.84912109375
# 	Epoch 20 complete! 	Average Loss:  5.348514591810783
# Overall Loss:  126182.15625
# 	Epoch 21 complete! 	Average Loss:  5.348076169391372
# Overall Loss:  126171.81298828125
# 	Epoch 22 complete! 	Average Loss:  5.3476925523615
# Overall Loss:  126162.7626953125
# 	Epoch 23 complete! 	Average Loss:  5.347265451146045
# Overall Loss:  126152.6865234375
# 	Epoch 24 complete! 	Average Loss:  5.347022055609423
# Overall Loss:  126146.9443359375
# 	Epoch 25 complete! 	Average Loss:  5.3467421507423065
# Overall Loss:  126140.3408203125
# 	Epoch 26 complete! 	Average Loss:  5.346540687123813
# Overall Loss:  126135.587890625
# 	Epoch 27 complete! 	Average Loss:  5.34643916883239
# Overall Loss:  126133.19287109375
# 	Epoch 28 complete! 	Average Loss:  5.3462920552716495
# Overall Loss:  126129.72216796875
# 	Epoch 29 complete! 	Average Loss:  5.346206825440032
# Overall Loss:  126127.71142578125
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/tm/gnjj0w_d6vj9x6q_ww3f6jsw0000gn/T/ipykernel_74063/1739851041.py in <module>
#       1 print("Start training VAE...")
#       2 model.train()
# ----> 3 z_an,kld=model_train(vae_spec=vae_dataset,model=model,optimizer=optimizer,loss_function=loss_function,epochs=epochs,batch_size=batch_size)
#
# ~/GES/Data_handling/vae.py in model_train(vae_spec, batch_size, optimizer, model, loss_function, epochs)
#     120             overall_loss += loss.item()
#     121
# --> 122             loss.backward()
#     123             optimizer.step()
#     124         z_an.append(z)
#
# ~/miniforge3/envs/astro/lib/python3.8/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# ~/miniforge3/envs/astro/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     152         retain_graph = create_graph
#     153
# --> 154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %% [markdown]
# ### Look at the KLD of main model.

# %%
for i in range (len(z_an)):
    z_an[i]=z_an[i].detach().numpy()

for i in range (len(kld)):
    kld[i]=kld[i].detach().numpy()

# %%
plt.plot(kld)

# %% [markdown]
# # Model evaluations

# %%
'''model1.eval()
(z_mean, z_var), (q_z, p_z), z1, x_=model1(torch.tensor(scaled_data).float())
z1=z1.detach().numpy()
x_=x_.detach().numpy()'''

# %%
model.eval()
x_recon=model(torch.tensor(scaled_data).float())[0].detach().numpy()
zmean=model(torch.tensor(scaled_data).float())[1].detach().numpy()
z=model(torch.tensor(scaled_data).float())[3].detach().numpy()

# %% [markdown]
# # Compare the reconstructions

# %%
plt.scatter(x_recon.transpose()[0], x_recon.transpose()[1],s=0.5)
#plt.scatter(x_.transpose()[0], x_.transpose()[1],s=0.5)

# %%
vae_data[['z1','z2','z3']]=z

# %%
#vae_data[['z11','z12','z13']]=z1

# %%
plt.figure(figsize=(15,10))
sn.pairplot(vae_data[['z1','z2','z3']])
#sn.pairplot(vae_data[['z11','z12','z13']])

# %%
fig = plt.figure(figsize=(15,15))


ax = fig.add_subplot(111, projection='3d') # Method 2

x=vae_data[vae_data['prob']<=0.9]
y=vae_data[vae_data['prob']>0.9]
ax.scatter(x['z1'], x['z2'], x['z3'],s=5,alpha=0.3)
ax.scatter(y['z1'], y['z2'], y['z3'],s=5)


plt.show()

# %%
plt.figure(figsize=(15,10))
sn.scatterplot(data=vae_data[vae_data['prob']<=0.9],x='z1',y='z2')
sn.scatterplot(data=vae_data[vae_data['prob']>0.9],x='z1',y='z2')
# Out:
# <AxesSubplot:xlabel='z1', ylabel='z2'>

# %% [markdown]
# # Now let us see if we can cluster well on this latent space

# %%
from sklearn.mixture import GaussianMixture

# %%
gm = GaussianMixture(n_components=3 ,random_state=0).fit(vae_data[['z1','z2','z3']].values)

# %%
i=1
plt.hist(gm.predict_proba(vae_data[vae_data['prob']<=0.9][['z1','z2','z3']].values).transpose()[i])
plt.hist(gm.predict_proba(vae_data[vae_data['prob']>0.9][['z1','z2','z3']].values).transpose()[i],color='r')
plt.show()

vae_data['prob2']=gm.predict_proba(vae_data[['z1','z2','z3']].values).transpose()[i]

# %% [markdown]
# This seems to be working okay.

# %% [markdown]
# Check it on a HR diagram

# %%
data_for_hr1_full=vae_data[vae_data['prob2']>0.9]
data_for_hr2_full=vae_data[vae_data['prob']>0.9]
both_solution=data_for_hr1_full[vae_data['prob']>0.9]
data_for_hr1_full=data_for_hr1_full[data_for_hr1_full['prob']<=0.9]
data_for_hr2_full=data_for_hr2_full[data_for_hr2_full['prob2']<=0.9]
# Out:
# /var/folders/tm/gnjj0w_d6vj9x6q_ww3f6jsw0000gn/T/ipykernel_74063/1280756406.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   both_solution=data_for_hr1_full[vae_data['prob']>0.9]

# %%
f, axes = plt.subplots(1, 1)
f.set_figheight(12)
f.set_figwidth(12)

scatter=data_for_hr1_full
sn.scatterplot(x=scatter['bp_rp'],y=scatter['mean_absolute_mag_g_band'],ax=axes,s=10,label='True Full solution',color='b')

scatter=data_for_hr2_full
sn.scatterplot(x=scatter['bp_rp'],y=scatter['mean_absolute_mag_g_band'],ax=axes,label='True astrometric',s=10,color='g')

scatter=both_solution
sn.scatterplot(x=scatter['bp_rp'],y=scatter['mean_absolute_mag_g_band'],ax=axes,label='both classified',s=10,color='red')

#axes.set_xlim(0,2.5)
axes.invert_yaxis()
plt.legend()
axes.set_title("NGC 6705 p>0.9")
plt.show()
