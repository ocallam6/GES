# %% [markdown]
# # 0.0 Imports

# %%
# %load_ext autoreload
# %autoreload 2

#this allows to change external without restarting kernel
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#plotting standards
sn.set_style('darkgrid') # darkgrid, white grid, dark, white and ticks
plt.rc('axes', titlesize=18)     # fontsize of the axes title
plt.rc('axes', labelsize=14)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=13)    # fontsize of the tick labels
plt.rc('ytick', labelsize=13)    # fontsize of the tick labels
plt.rc('legend', fontsize=13)    # legend fontsize
plt.rc('font', size=13)          # controls default text sizes

# %%
from astropy.io import fits
import os

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import sklearn.decomposition
import seaborn as sn
import pickle
from sklearn.preprocessing import MaxAbsScaler, RobustScaler, normalize
if("Spectral_analysis" in os.getcwd()):
    os.chdir("../")

from Data_handling.pca_functions import Pca_Fitting

from Data_handling.vae import Encoder,Decoder, VAE , loss_function, model_train


os.chdir("Spectral_analysis")
os.getcwd()
# Out:
# '/Users/mattocallaghan/GES/Spectral_analysis'

# %% [markdown]
# # 1.0 Data input for HR10 Sample
#
# THE HR10 Giraffe spectra have been selected. We will use the data handling function to create a list of these
# spectra with their object names. We will get a list of spectrum classes.

# %%
os.chdir('../')
from Data_handling.spectra_object import get_data
os.chdir('Parameter_files')
HR10=pd.read_csv('HR10_parameter_with_file_names_for_spectra.csv')
os.chdir('../Data')
HR10['spectrum']=HR10['hr10_file'].apply(get_data)

# %% [markdown]
# # 1.1 Learning spectrum
#
# Create spectrum which can be used for machine learning algorithms

# %% [markdown]
# We will replace highly erroneous flux values with the median for that spectrum. Make a signal to noise ratio cut.

# %%
def fill_high_error_data(spectrum,n_sigma=3):
    try:    #technical thing
        median = spectrum['flux_err'].median()
        std=spectrum['flux_err'].std()
        bound=median+n_sigma*std
        outliers = (spectrum['flux_err'])>bound
        spectrum['flux'][outliers] = np.nan
        spectrum['flux']=spectrum['flux'].fillna(median)
        return spectrum
    except:
        return 0 #this is done if that there is no values in the sp

# %%
HR10['spectrum']=HR10['spectrum'].apply(fill_high_error_data)

# %%
def row_type_isnt_int(row):
    return type(row)!=int

# %%
HR10=HR10[HR10['spectrum'].apply(row_type_isnt_int)]
#drop the spectrum indices with no values.

# %% [markdown]
# Number of datapoints with above certain SNR

# %%
print('Fraction of SNR we will use')
sum(HR10['SNR']>=5.0)/sum(HR10['SNR']>=0.0)
# Out:
# Fraction of SNR we will use
# 0.9053098236775818

# %% [markdown]
# Make the SNR cut

# %%
HR10=HR10[HR10['SNR']>=20.0]

# %%
HR10.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/tm/gnjj0w_d6vj9x6q_ww3f6jsw0000gn/T/ipykernel_9684/3069817066.py in <module>
# ----> 1 HR10.reset_index(inplace=True)
#
# ~/miniforge3/envs/astro/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/miniforge3/envs/astro/lib/python3.8/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5797                     )
#    5798
# -> 5799                 new_obj.insert(0, name, level_values)
#    5800
#    5801         new_obj.index = new_index
#
# ~/miniforge3/envs/astro/lib/python3.8/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    4412         if not allow_duplicates and column in self.columns:
#    4413             # Should this be a different kind of error??
# -> 4414             raise ValueError(f"cannot insert {column}, already exists")
#    4415         if not isinstance(loc, int):
#    4416             raise TypeError("loc must be int")
#
# ValueError: cannot insert level_0, already exists

# %%
learning_spectra=[]
for i in range(0,len(HR10['spectrum'])):
    learning_spectra.append(HR10['spectrum'][i]['flux'])
    
learning_spectra=np.array(learning_spectra)
np.shape(learning_spectra)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniforge3/envs/astro/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/miniforge3/envs/astro/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/miniforge3/envs/astro/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 4
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/tm/gnjj0w_d6vj9x6q_ww3f6jsw0000gn/T/ipykernel_9684/2314707950.py in <module>
#       1 learning_spectra=[]
#       2 for i in range(0,len(HR10['spectrum'])):
# ----> 3     learning_spectra.append(HR10['spectrum'][i]['flux'])
#       4
#       5 learning_spectra=np.array(learning_spectra)
#
# ~/miniforge3/envs/astro/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~/miniforge3/envs/astro/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~/miniforge3/envs/astro/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 4

# %% [markdown]
# # 1.2 Normalise the data
# Divide by a constant.

# %%
scaler=MaxAbsScaler()
def normalised_pca(list_X): 
    X_train_scaled = scaler.fit_transform(list_X)
    return X_train_scaled
learning_spectra=normalised_pca(learning_spectra.transpose()).transpose()

# %% [markdown]
# # 3.0 Variational Autoencoders.

# %%
import torch
import torch.nn as nn 
import torch.nn.functional as F 
from torch.optim import Adam
from torch.utils.data import DataLoader


DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # 3.0.1 Set Model Hyperparameters

# %%
#learning_spectra=learning_spectra-x_mean

# %%
batch_size = 13313 #factor for 1090
lr = 1e-3
epochs = 50

# %% [markdown]
# # 3.1 Load in the Data

# %%
vae_spec=DataLoader(torch.tensor(learning_spectra),batch_size=batch_size)

# %% [markdown]
# # 3.2 Model Setup

# %% [markdown]
# ## 3.2.1 Set latent variables dimension

# %%
zdim=5

# %% [markdown]
# # 3.2.2 Define the VAE Model and Optimiser

# %%
encoder = Encoder(input_dim=learning_spectra.shape[1], hidden_dims=[50,10], z_dim=zdim,dropout=.2)
decoder = Decoder(output_dim=learning_spectra.shape[1], hidden_dims = [10,50], z_dim=zdim,dropout=.2)
model = VAE(Encoder=encoder, Decoder=decoder).to(DEVICE)
optimizer=Adam(model.parameters(),lr=lr)

# %% [markdown]
# # 3.3 Train model

# %%
print("Start training VAE...")
model.train()
model_train(vae_spec=vae_spec,model=model,optimizer=optimizer,loss_function=loss_function,epochs=epochs,batch_size=batch_size)
# Out:
# Start training VAE...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/tm/gnjj0w_d6vj9x6q_ww3f6jsw0000gn/T/ipykernel_9684/233786924.py in <module>
#       1 print("Start training VAE...")
#       2 model.train()
# ----> 3 model_train(vae_spec=vae_spec,model=model,optimizer=optimizer,loss_function=loss_function,epochs=epochs,batch_size=batch_size)
#
# ~/GES/Data_handling/vae.py in model_train(vae_spec, batch_size, optimizer, model, loss_function, epochs)
#     115             optimizer.zero_grad()
#     116
# --> 117             x_hat, mean, log_var, z = model(x)
#     118             loss, KLD = loss_function(x, x_hat, mean, log_var)
#     119
#
# ~/miniforge3/envs/astro/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/GES/Data_handling/vae.py in forward(self, x)
#      83
#      84     def forward(self,x):
# ---> 85         z,mean,log_var=self.Encoder(x)
#      86         x_recon=self.Decoder(z)
#      87         return x_recon, mean, log_var, z
#
# ~/miniforge3/envs/astro/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/GES/Data_handling/vae.py in forward(self, x)
#      38
#      39     def forward(self,x):
# ---> 40         hidden_layer1=(self.relu(self.hidden1(x)))
#      41         hidden_layer2=(self.relu(self.hidden2(hidden_layer1)))
#      42
#
# ~/miniforge3/envs/astro/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniforge3/envs/astro/lib/python3.8/site-packages/torch/nn/modules/linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# ~/miniforge3/envs/astro/lib/python3.8/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1846     if has_torch_function_variadic(input, weight, bias):
#    1847         return handle_torch_function(linear, (input, weight, bias), input, weight, bias=bias)
# -> 1848     return torch._C._nn.linear(input, weight, bias)
#    1849
#    1850
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (13313x5541 and 1x50)

# %% [markdown]
# # 3.4 Reconstruction Accuracy

# %% [markdown]
# # try remove the mean to see what happens

# %%
os.chdir('../')

# %%
input_names = ['Spec']
output_names = ['Spec reconstructed']
torch.onnx.export(model, torch.tensor(learning_spectra), 'rnn.onnx', input_names=input_names, output_names=output_names)

# %%
#from torchviz import make_dot

#make_dot(model(torch.tensor(learning_spectra)), params=dict(list(model.named_parameters()))).render("vae_spec", format="png")

# %%
print(model.eval())
# Out:
# VAE(
#   (Encoder): Encoder(
#     (hidden1): Linear(in_features=5541, out_features=50, bias=True)
#     (hidden2): Linear(in_features=50, out_features=10, bias=True)
#     (nn_mu): Linear(in_features=10, out_features=2, bias=True)
#     (nn_log_sigma): Linear(in_features=10, out_features=2, bias=True)
#     (dropout): Dropout(p=0.2, inplace=False)
#     (tanh): Tanh()
#     (relu): ReLU()
#     (softplus): Softplus(beta=1, threshold=20)
#   )
#   (Decoder): Decoder(
#     (hidden1): Linear(in_features=2, out_features=10, bias=True)
#     (hidden2): Linear(in_features=10, out_features=50, bias=True)
#     (nn_out): Linear(in_features=50, out_features=5541, bias=True)
#     (dropout): Dropout(p=0.2, inplace=False)
#     (tanh): Tanh()
#     (relu): ReLU()
#     (sigmoid): Sigmoid()
#   )
# )

# %%
learning_spectra=learning_spectra[:,np.newaxis,:]

# %%
model.eval()
x_recon=model(torch.tensor(learning_spectra))[0].detach().numpy()
z=model(torch.tensor(learning_spectra))[3].detach().numpy()

# %%
x_recon[0]
# Out:
# array([[0.7436611, 0.7414952, 0.7494728, ..., 0.9055828, 0.9074844,
#         0.9067496]], dtype=float32)

# %%
plt.figure(figsize=(15,10))
plt.plot(x_recon[0][0],label='VAE Vanilla')
plt.plot(x_recon[200][0],label='VAE Vanilla')
plt.plot(x_recon[500][0],label='VAE Vanilla')


plt.legend()
plt.title('Plot of VAE reconstructed spectrum')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot(learning_spectra[200][0],label='original')
plt.plot(x_recon[200][0],label='VAE Vanilla',color='red')
#plt.ylim(0.005,0.020)
plt.title('Plot of original and VAE reconstructed spectrum')
plt.legend()
plt.show()

# %% [markdown]
# # 3.5 Analysis of Latent Parameters

# %%
x_mean=x_recon

# %%
z=z.reshape([z.shape[0],z.shape[1]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/tm/gnjj0w_d6vj9x6q_ww3f6jsw0000gn/T/ipykernel_9684/1431153446.py in <module>
# ----> 1 z=z.reshape([z.shape[0],z.shape[1]])
#
# ValueError: cannot reshape array of size 53252 into shape (26626,1)

# %%
z
# Out:
# array([[ 0.08907807, 11.249246  ],
#        [ 0.5351601 , 12.668684  ],
#        [-0.3924629 ,  9.240371  ],
#        ...,
#        [ 0.5672588 , 12.474799  ],
#        [-0.12880036, 10.32419   ],
#        [ 0.40444934, 11.925554  ]], dtype=float32)

# %%
pca_coeff=pd.DataFrame(data=z)
analysis=HR10.loc[:, HR10.columns != 'spectrum']

# %%
param=['DIST_GAIA','TEFF', 'LOGG', 'FEH', 'VRAD']#, 'XI']

# %%
i=1
pca_analysis=pd.concat([analysis[param],pca_coeff],axis=1)
pca_analysis=pca_analysis[pca_analysis[param[i]]!='nan']

pca_analysis[param[i]]=pca_analysis[param[i]].astype(float)

plt.figure(figsize=(15,10))
sn.scatterplot(data=pca_analysis,x=2,y=6, hue=param[i], palette="ch:r=-3,l=0.9")

plt.title('Plot of spectra components')
plt.ylabel('Second PCA component')
plt.xlabel('First PCA Component')

sn.heatmap
# Out:
# <function seaborn.matrix.heatmap(data, *, vmin=None, vmax=None, cmap=None, center=None, robust=False, annot=None, fmt='.2g', annot_kws=None, linewidths=0, linecolor='white', cbar=True, cbar_kws=None, cbar_ax=None, square=False, xticklabels='auto', yticklabels='auto', mask=None, ax=None, **kwargs)>

# %%
corr=pca_analysis.corr().loc[param]
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# /var/folders/tm/gnjj0w_d6vj9x6q_ww3f6jsw0000gn/T/ipykernel_9085/3384151885.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_a2def_row0_col0, #T_a2def_row1_col1, #T_a2def_row1_col5, #T_a2def_row1_col6, #T_a2def_row2_col2, #T_a2def_row3_col3, #T_a2def_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a2def_row0_col1, #T_a2def_row3_col4, #T_a2def_row3_col5, #T_a2def_row3_col6, #T_a2def_row4_col0, #T_a2def_row4_col2, #T_a2def_row4_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a2def_row0_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_a2def_row0_col3 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_a2def_row0_col4 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_a2def_row0_col5 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_a2def_row0_col6 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_a2def_row1_col0 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_a2def_row1_col2 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_a2def_row1_col3 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_a2def_row1_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_a2def_row2_col0 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_a2def_row2_col1 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_a2def_row2_col3 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_a2def_row2_col4 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_a2def_row2_col5 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_a2def_row2_col6 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_a2def_row3_col0 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_a2def_row3_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_a2def_row3_col2 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_a2def_row4_col1 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_a2def_row4_col5 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_a2def_row4_col6 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# </style>
# <table id="T_a2def_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >DIST_GAIA</th>
#       <th class="col_heading level0 col1" >TEFF</th>
#       <th class="col_heading level0 col2" >LOGG</th>
#       <th class="col_heading level0 col3" >FEH</th>
#       <th class="col_heading level0 col4" >VRAD</th>
#       <th class="col_heading level0 col5" >0</th>
#       <th class="col_heading level0 col6" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2def_level0_row0" class="row_heading level0 row0" >DIST_GAIA</th>
#       <td id="T_a2def_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_a2def_row0_col1" class="data row0 col1" >-0.04</td>
#       <td id="T_a2def_row0_col2" class="data row0 col2" >0.07</td>
#       <td id="T_a2def_row0_col3" class="data row0 col3" >-0.03</td>
#       <td id="T_a2def_row0_col4" class="data row0 col4" >-0.06</td>
#       <td id="T_a2def_row0_col5" class="data row0 col5" >-0.06</td>
#       <td id="T_a2def_row0_col6" class="data row0 col6" >-0.07</td>
#     </tr>
#     <tr>
#       <th id="T_a2def_level0_row1" class="row_heading level0 row1" >TEFF</th>
#       <td id="T_a2def_row1_col0" class="data row1 col0" >-0.04</td>
#       <td id="T_a2def_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_a2def_row1_col2" class="data row1 col2" >0.47</td>
#       <td id="T_a2def_row1_col3" class="data row1 col3" >0.01</td>
#       <td id="T_a2def_row1_col4" class="data row1 col4" >0.06</td>
#       <td id="T_a2def_row1_col5" class="data row1 col5" >0.68</td>
#       <td id="T_a2def_row1_col6" class="data row1 col6" >0.63</td>
#     </tr>
#     <tr>
#       <th id="T_a2def_level0_row2" class="row_heading level0 row2" >LOGG</th>
#       <td id="T_a2def_row2_col0" class="data row2 col0" >0.07</td>
#       <td id="T_a2def_row2_col1" class="data row2 col1" >0.47</td>
#       <td id="T_a2def_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_a2def_row2_col3" class="data row2 col3" >0.38</td>
#       <td id="T_a2def_row2_col4" class="data row2 col4" >-0.08</td>
#       <td id="T_a2def_row2_col5" class="data row2 col5" >0.11</td>
#       <td id="T_a2def_row2_col6" class="data row2 col6" >0.09</td>
#     </tr>
#     <tr>
#       <th id="T_a2def_level0_row3" class="row_heading level0 row3" >FEH</th>
#       <td id="T_a2def_row3_col0" class="data row3 col0" >-0.03</td>
#       <td id="T_a2def_row3_col1" class="data row3 col1" >0.01</td>
#       <td id="T_a2def_row3_col2" class="data row3 col2" >0.38</td>
#       <td id="T_a2def_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_a2def_row3_col4" class="data row3 col4" >-0.16</td>
#       <td id="T_a2def_row3_col5" class="data row3 col5" >-0.35</td>
#       <td id="T_a2def_row3_col6" class="data row3 col6" >-0.35</td>
#     </tr>
#     <tr>
#       <th id="T_a2def_level0_row4" class="row_heading level0 row4" >VRAD</th>
#       <td id="T_a2def_row4_col0" class="data row4 col0" >-0.06</td>
#       <td id="T_a2def_row4_col1" class="data row4 col1" >0.06</td>
#       <td id="T_a2def_row4_col2" class="data row4 col2" >-0.08</td>
#       <td id="T_a2def_row4_col3" class="data row4 col3" >-0.16</td>
#       <td id="T_a2def_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_a2def_row4_col5" class="data row4 col5" >0.13</td>
#       <td id="T_a2def_row4_col6" class="data row4 col6" >0.11</td>
#     </tr>
#   </tbody>
# </table>
