# %%
import pandas as pd
import os
from os import listdir
from os.path import isfile, join
mypath=os.getcwd()
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
onlyfiles
# Out:
# ['g20120927_00030_final_fn.fit',
#  'g20150827_00018_final_fn.fit',
#  'g20130218_00003_final_fn.fit',
#  'g20150605_00045_final_fn.fit',
#  'g20130628_00048_final_fn.fit',
#  'g20150308_00002_final_fn.fit',
#  'g20150204_00019_final_fn.fit',
#  'g20130117_00021_final_fn.fit',
#  'g20140407_00002_final_fn.fit',
#  'crtdownloadscrpt.sh',
#  '.DS_Store',
#  'g20150308_00032_final_fn.fit',
#  'g20140219_00024_final_fn.fit',
#  'g20150801_00022_final_fn.fit',
#  'g20141104_00018_final_fn.fit',
#  'g20140910_00002_final_fn.fit',
#  'g20120410_00025_final_fn.fit',
#  'g20150703_00005_final_fn.fit',
#  'g20120313_00027_final_fn.fit',
#  'g20120216_00011_final_fn.fit',
#  'g20120315_00038_final_fn.fit',
#  'g20120312_00030_final_fn.fit',
#  'g20150705_00002_final_fn.fit',
#  'g20120214_00031_final_fn.fit',
#  'g20150310_00002_final_fn.fit',
#  'g20120426_00022_final_fn.fit',
#  'g20131209_00002_final_fn.fit',
#  'g20120215_00010_final_fn.fit',
#  'g20120829_00015_final_fn.fit',
# ...

# %%
full_df=pd.read_csv('spectra_w_down.csv')
# Out:
# /Users/mattocallaghan/miniforge3/envs/astro/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (0,1,4,5,6,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df=full_df.iloc[11:]
df=df[df['cName.1']!=df['cName.1'].tail(1).values[0]] #weird expression to get rid of ones without a none name
df
# Out:
#                # specGroupId                specId             cName    wg  \
# 11                         2                 16510  00000014-6003143  WG15
# 12                         2                 18684  00000014-6003143  WG15
# 13                         3                 16511  00000097-5946444  WG15
# 14                         3                 18685  00000097-5946444  WG15
# 15                         4                 16512  00000117-5951314  WG15
# ...                      ...                   ...               ...   ...
# 120565                204079                125178  16355294-2812579  WG15
# 120566                204079                125181  16355294-2812579  WG15
# 121468                204980                113688  18274431+0631059  WG15
# 122061                205573                144000  22563382+1633085  WG15
# 122062                205573                144014  22563382+1633085  WG15
#
# ...

# %%
sliced=df.iloc[::10, :]
sliced_practice=df.iloc[::100, :]
sliced
# Out:
#                # specGroupId                specId             cName    wg  \
# 11                         2                 16510  00000014-6003143  WG15
# 25                        11                 16519  00000352-6004026  WG15
# 37                        18                 16526  00000609-5959420  WG15
# 48                        24                 16531  00000884-5504433  WG15
# 59                        30                 16537  00001164-5947449  WG15
# ...                      ...                   ...               ...   ...
# 119851                203410                119258  10462710-5949456  WG15
# 119868                203417                119269  10463474-5951394  WG15
# 119884                203423                119280  10464612-5952505  WG15
# 119901                203430                119288  10465557-5950388  WG15
# 119921                203440                119302  10471406-5947593  WG15
#
# ...

# %%
sliced_practice.to_csv('practice.csv')

# %%
import matplotlib.pyplot as plt
plt.hist(logg)
# Out:
# (array([26034.,     0.,     0.,     0.,     0.,     0.,     0.,     0.,
#             0., 96323.]),
#  array([-9.99999500e+08, -8.99999549e+08, -7.99999599e+08, -6.99999648e+08,
#         -5.99999698e+08, -4.99999747e+08, -3.99999797e+08, -2.99999846e+08,
#         -1.99999896e+08, -9.99999454e+07,  5.09888100e+00]),
#  <BarContainer object of 10 artists>)
