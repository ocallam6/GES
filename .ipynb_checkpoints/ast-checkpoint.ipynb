# %%
from astropy.io import fits

import matplotlib.pyplot as plt

fits_image_filename = 'g20150827_00018_final_fn.fit'

hdul = fits.open(fits_image_filename)

hdul[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 7441 / length of data axis 1
# NAXIS2  =                  431 / length of data axis
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# ORIGIN  = 'ESO     '                    / European Southern Observatory
# DATE    = '2015-08-28T04:40:40.533'     / UT date when this file was written
# TELESCOP= 'ESO-VLT-U2'                  / ESO Telescope Name
# INSTRUME= 'GIRAFFE '                    / Name of the Instrument.
# OBJECT  = 'GES_Cl_000046_294211' / Original target.
# RA      =             0.192512          / 00:00:46.2 RA (J2000) pointing
# ...

# %%
s=hdul[0].data
len(s[0])
# Out:
# 7441

# %%
plt.plot(s[0])

plt.plot(s[2])
#zeems these are different spectrum from the same observation
